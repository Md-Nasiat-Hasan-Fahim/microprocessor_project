# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# ...
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-36d47t8b
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-36d47t8b
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 4.6 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6859 sha256=0f1460826bcf55157e4e7a0d8e1f656bb209378e413a2e2f77510e2440f6b511
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kpinpzw2/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
# ...

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from normalizer import normalize # 

model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/banglat5_nmt_en_bn")
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/banglat5_nmt_en_bn", use_fast=False)
# Out:
# config.json:   0%|          | 0.00/766 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# ...

# %%
input_sentence = """Answer 1 maintains a clear and focused narrative, highlighting Carl Sagan's reflection on the photograph and its philosophical significance without deviating from the main topic. The explanation is straightforward and avoids redundant phrases."""

# %%
input_ids = tokenizer(normalize(input_sentence), return_tensors="pt").input_ids
generated_tokens = model.generate(input_ids)
decoded_tokens = tokenizer.batch_decode(generated_tokens)[0]
decoded_tokens = decoded_tokens.strip('<pad>').strip('</s>').strip(' ')
print(decoded_tokens)
# Out:
# উত্তর ১ একটি স্পষ্ট এবং ফোকাস আখ্যান বজায় রাখে, ছবির উপর কার্ল সাগানের প্রতিফলন এবং মূল বিষয় থেকে বিচ্যুত না হয়ে এর দার্শনিক তাৎপর্য তুলে ধরে। ব্যাখ্যাটি সরাসরি এবং অপ্রয়োজনীয় বাক্যাংশ এড়িয়ে চলে।
